# %%
l = [23,45,67,85,12]

# %%
print(l)
# Out:
# [23, 45, 67, 85, 12]

# %% [markdown]
# # list are hetro and dupicates are allowed

# %%
l1 = [45,78,75,43,23,"python","java",21,22]

# %%
print(l1)
# Out:
# [45, 78, 75, 43, 23, 'python', 'java', 21, 22]

# %%
# lists are ordered

# %%
l1
# Out:
# [45, 78, 75, 43, 23, 'python', 'java', 21, 22]

# %%
l1[2]
# Out:
# 75

# %%
l1[-3]
# Out:
# 'java'

# %%
l1[-2]
# Out:
# 21

# %%
# list are mutable

# %%
l1[1] = 100

# %%
l1
# Out:
# [45, 100, 75, 43, 23, 'python', 'java', 21, 22]

# %%
l1[-3] =True

# %%
l1
# Out:
# [45, 100, 75, 43, 23, 'python', True, 21, 22]

# %%
l=[21,23,45,67,89,11]

# %%
l
# Out:
# [21, 23, 45, 67, 89, 11]

# %%
l[1:4]
# Out:
# [23, 45, 67]

# %%
l[1:2]
# Out:
# [23]

# %%
l[0:6:2]
# Out:
# [21, 45, 89]

# %%
l[::2]
# Out:
# [21, 45, 89]

# %%
# reverse list

# %%
l[::-1]
# Out:
# [11, 89, 67, 45, 23, 21]

# %%
l[1:4]=[100,200,300]

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
l1=[12,34,56,23]

# %%
del l1[-2]

# %%
l1
# Out:
# [12, 34, 23]

# %%
# membership opreator

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
89 in l
# Out:
# True

# %%
1039 in l
# Out:
# False

# %%
l*2
# Out:
# [21, 100, 200, 300, 89, 11, 21, 100, 200, 300, 89, 11]

# %%
'aditi' * 3
# Out:
# 'aditiaditiaditi'

# %%
l + [60,70,80]
# Out:
# [21, 100, 200, 300, 89, 11, 60, 70, 80]

# %%
# take 2 different list and add them

# %%
l2 =[14,23,45,22]
l3=[78,90,98,87]

# %%
l4 = l2+l3

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
# ierate over list and print square of each element

# %%
for i in l:
    print(i**2,end = ' ')
# Out:
# 441 10000 40000 90000 7921 121

# %%
# print odd number in the list1

# %%
for i in l:
    if i % 2 == 1:
        print(i,end = ' ')
# Out:
# 21 89 11

# %%
# list comprehension ->[expression for_loop if_condition]

# %%
newl = [i**2 for i in l]

# %%
newl
# Out:
# [441, 10000, 40000, 90000, 7921, 121]

# %%
names = ['aryan','atharv','samruddhi','Sukanya','shivraj']

# %%
# create a new list with names which 's' or 'S'

# %%
newl3 = [name for name in names if 's' in name.lower()]

# %%
newl3
# Out:
# ['samruddhi', 'Sukanya', 'shivraj']

# %%
for i in names:
    if i.lower().startswith('s'):
        print(i)
# Out:
# samruddhi
# Sukanya
# shivraj

# %%
newl4 = [i for i in names if i.lower().startswith('s')]

# %%
newl4
# Out:
# ['samruddhi', 'Sukanya', 'shivraj']

# %%
# functions

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
len(l)
# Out:
# 6

# %%
max(l)
# Out:
# 300

# %%
min(l)
# Out:
# 11

# %%
sorted(l)
# Out:
# [11, 21, 89, 100, 200, 300]

# %%
sorted(l,reverse = True)
# Out:
# [300, 200, 100, 89, 21, 11]

# %%
# list method

# %%
# append

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
l.append(1000)

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11, 1000]

# %%
l1 = [1,2,3,4]
l2 = [1,2,3,4]

# %%
l1.append([100,200])
l2.extend([100,200])

# %%
l1
# Out:
# [1, 2, 3, 4, [100, 200]]

# %%
l2
# Out:
# [1, 2, 3, 4, 100, 200]

# %%
l1[3]
# Out:
# 4

# %%
l1
# Out:
# [1, 2, 3, 4, [100, 200]]

# %%
# insert

# %%
 l=[21, 100, 200, 300, 89, 11]

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
l.insert(1,78)

# %%
l
# Out:
# [21, 78, 100, 200, 300, 89, 11]

# %%
l.remove(78)

# %%
l
# Out:
# [21, 100, 200, 300, 89, 11]

# %%
l.pop()
# Out:
# 11

# %%
l
# Out:
# [21, 100, 200, 300, 89]

# %%
l.pop(3)
# Out:
# 300

# %%
l
# Out:
# [21, 100, 200, 89]

# %%
l.index(89)
# Out:
# 3

# %%
l.sort()

# %%
l
# Out:
# [21, 89, 100, 200]

# %% [raw]
# l.sort(reverse = True)

# %%
l
# Out:
# [21, 89, 100, 200]
