# %%
l = [34,56,12,48,19,34,10]

# %%
"""

iterrate over the list 
print the in the format => index => value

eg...
0 => 34
1 => 56
""";

# %%
for i in range(len(l)):
    print(i,"=>",l[i])
# Out:
# 0 => 34
# 1 => 56
# 2 => 12
# 3 => 48
# 4 => 19
# 5 => 34
# 6 => 10

# %%
for i in l:
    print(f"{l.index(i)} =>{i}")
# Out:
# 0 =>34
# 1 =>56
# 2 =>12
# 3 =>48
# 4 =>19
# 0 =>34
# 6 =>10

# %%
list(enumerate(l))
# Out:
# [(0, 34), (1, 56), (2, 12), (3, 48), (4, 19), (5, 34), (6, 10)]

# %%
for ind,val in enumerate(l):
    print(f"{ind} =>{val}")
# Out:
# 0 =>34
# 1 =>56
# 2 =>12
# 3 =>48
# 4 =>19
# 5 =>34
# 6 =>10

# %%
list (enumerate(l,start=101))
# Out:
# [(101, 34), (102, 56), (103, 12), (104, 48), (105, 19), (106, 34), (107, 10)]

# %% [markdown]
# ## Tuple

# %%
t = [56,78,99,12,56,True,"hello"]

# %%
t
# Out:
# [56, 78, 99, 12, 56, True, 'hello']

# %% [markdown]
# tuple are hetro and dupicates are allowed

# %%
t1 = [45,78,75,43,23,"python","java",21,22]

# %%
t1
# Out:
# [45, 78, 75, 43, 23, 'python', 'java', 21, 22]

# %%
t[5] # ordered
# Out:
# True

# %%
t[5] = 8 # immutable

# %%
# different ways of creating a types

# %%
t1 = (67,)

# %%
type(t1)
# Out:
# tuple

# %%
t2 = (67)

# %%
type(t2)
# Out:
# int

# %%
t3 =()

# %%
type(t3)
# Out:
# tuple

# %%
t4 = 7,

# %%
type(t4)
# Out:
# tuple

# %%
t
# Out:
# [56, 78, 99, 12, 56, 8, 'hello']

# %%
l1 = list(t)
l1
# Out:
# [56, 78, 99, 12, 56, 8, 'hello']

# %%
l1[-3] =100
t =tuple(l1)
t
# Out:
# (56, 78, 99, 12, 100, 8, 'hello')

# %%
t5 = (67,43,45,32,[65,68],89,100)

# %%
t5
# Out:
# (67, 43, 45, 32, [65, 68], 89, 100)

# %%
type(t5)
# Out:
# tuple

# %%
t5[4][0] = 1000

# %%
t5
# Out:
# (67, 43, 45, 32, [1000, 68], 89, 100)

# %%
# copying

# %%
l = [34,56,12,48,19,34,10]

# %%
z = l

# %%
z
# Out:
# [34, 56, 12, 48, 19, 34, 10]

# %%
l[0] = 1000

# %%
l
# Out:
# [1000, 56, 12, 48, 19, 34, 10]

# %%
l = [34,56,12,48,[19,56],34,10]

# %%
z = l.copy()

# %%
z
# Out:
# [34, 56, 12, 48, [19, 56], 34, 10]

# %%
l[0] = 1000

# %%
l
# Out:
# [1000, 56, 12, 48, [19, 56], 34, 10]

# %%
z
# Out:
# [34, 56, 12, 48, [19, 56], 34, 10]

# %%
l[4][0] = 12

# %%
l
# Out:
# [1000, 56, 12, 48, [12, 56], 34, 10]

# %%
z
# Out:
# [34, 56, 12, 48, [12, 56], 34, 10]

# %%
# function

# %%
t = (34,56,12,89,12,89)

# %%
max(t)
# Out:
# 89

# %%
min(t)
# Out:
# 12

# %%
sorted(t)
# Out:
# [12, 12, 34, 56, 89, 89]

# %%
dir(t)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %% [markdown]
# sets

# %%
s = {34,56,1123,123,True,"hello"}

# %%
s # duplicates are not allowed but hetro allowed
# Out:
# {1123, 123, 34, 56, True, 'hello'}

# %%
s[0] # unoreded
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s.add(57)

# %%
s # mutable
# Out:
# {1123, 123, 34, 56, 57, True, 'hello'}

# %%
s = {}

# %%
type(s)
# Out:
# dict

# %%
s = set()
type(s)
# Out:
# set

# %%
s
# Out:
# set()

# %%
# remove and discard

# %%
s.remove(56) # key error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 s.remove(56) # key error
#
# KeyError: 56

# %%
s = {4,5,67,89,100}

# %%
s
# Out:
# {4, 5, 67, 89, 100}

# %%
s.remove(4)

# %%
s
# Out:
# {5, 67, 89, 100}

# %%
s.remove(56)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 s.remove(56)
#
# KeyError: 56

# %%
s.discard(5)

# %%
s
# Out:
# {67, 89, 100}

# %%
s.discard(56)

# %%
s
# Out:
# {67, 89, 100}

# %%
# set operation

# %%
s1 = {1,2,3,4,5}
s2 = {4,5,6,7,8}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1 | s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1.intersection(s2)
# Out:
# {4, 5}

# %%
s1.difference(s2)
# Out:
# {1, 2, 3}

# %%
s1.symmetric_difference(s2)
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
s1 = {1,2,3,4,5,6,7,8}
s2 = {4,5,6,7,8}
s3={1,2,3}

# %%
s2.issubset(s1)
# Out:
# True

# %%
s2.issuperset(s2)
# Out:
# True

# %%
s3.issubset(s2)
# Out:
# False

# %%
s = frozenset({4,6,3,2})

# %%
type(s)
# Out:
# frozenset

# %%
s
# Out:
# frozenset({2, 3, 4, 6})

# %%
s.add(100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 s.add(100)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %% [markdown]
# # dictionary

# %%
d = {1: "one", 2: "two",3:"three"}

# %%
d
# Out:
# {1: 'one', 2: 'two', 3: 'three'}

# %%
type(d)
# Out:
# dict

# %%
d[1]
# Out:
# 'one'

# %%
d = {1: "one", 2: "two",3:"three" , "four":4}

# %%
d # hetro
# Out:
# {1: 'one', 2: 'two', 3: 'three', 'four': 4}

# %%
# keys are unique and values can be duplicate
d =  {1: "one", 2: "two",3:"three" , "four":4,'ok':4}

# %%
d
# Out:
# {1: 'one', 2: 'two', 3: 'three', 'four': 4, 'ok': 4}

# %%
d['ok'] = [5,6,7]

# %%
d # mutable
# Out:
# {1: 'one', 2: 'two', 3: 'three', 'four': 4, 'ok': [5, 6, 7]}

# %%
# ways to create dict

# %%
l = [(2,"two"),(3,"three"),(4,"four")]

# %%
dict(l)
# Out:
# {2: 'two', 3: 'three', 4: 'four'}

# %%
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
d.keys()
# Out:
# dict_keys([1, 2, 3, 'four', 'ok'])

# %%
d.values()
# Out:
# dict_values(['one', 'two', 'three', 4, [5, 6, 7]])
