# %%
"""

create a class called student 
create 2-3 object having attributes name,age

create a method which add a skill (eg..python , mL,java) to the student
where u can view the info of it later (i.e skills learned by a student)

""";

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age
        self.skills = []

    def add_skill(self, skill):
        self.skills.append(skill)

    def display(self):
        print("Name :", self.name)
        print("Age :", self.age)
        print("Skills :", self.skills)
        print()


# Objects
s1 = Student("Aarti", 20)
s2 = Student("Rahul", 21)
s3 = Student("Priya", 19)

# Add skills
s1.add_skill("Python")
s1.add_skill("Java")

s2.add_skill("Machine Learning")

s3.add_skill("Python")
s3.add_skill("C++")

# Display information
s1.display()
s2.display()
s3.display()
# Out:
# Name : Aarti
# Age : 20
# Skills : ['Python', 'Java']
#
# Name : Rahul
# Age : 21
# Skills : ['Machine Learning']
#
# Name : Priya
# Age : 19
# Skills : ['Python', 'C++']

# %% [markdown]
# inheritance

# %%
class person:
    insti = "MITU"


    def __init__(self,age,ht):
        self.age = age
        self.ht =ht

    def show(self):
        print(f"age ->{self.age} , height ->{self.ht}.institute ->{self.insti}")

# %%
class  Ravi(person):
   
    def __init__(self,age,ht,sal):
        super().__init__(age ,ht)
        self.sal = sal

    def show_sal(self):
        print(f"salary is {self.sal}")

# %%
a = Ravi(20,5.9,89000)

# %%
a.show_sal()
# Out:
# salary is 89000

# %%
a.show()
# Out:
# age ->20 , height ->5.9.institute ->MITU

# %% [markdown]
# polymorphism

# %%
class Animal:

    def speak(self):
        return "sound of an animal"

# %%
class Dog(Animal):

    def speak(self):
        return "woof!!!"


class Cat(Animal):

    def speak(self):
        return "meow!!!"

# %%
d = Dog()
c = Cat()

# %%
d.speak()
# Out:
# 'woof!!!'

# %%
# simple menu driver with oop

# %%
# add item , view , exit(grocery list)

# %%
class meanuapp:

    def __init__(self):
        self.itemlist = []

    def show_menu(self):

        print("menu\n1.add items\n2.view items\n3.exit")


    def add_item(self):
        item = input("enter the item name :")
        self.itemlist.append(item)

    def view_item(self):
        return self.itemlist

    def run(self):

        while True:

            self.show_menu()

            ch = ini(input("enter the choice"))

            if ch == 1:
                self.add_items()
            elif ch == 2:
                self.add_item()
            elif ch == 3:
                break
            else:
                return 'invalid choice'

# %%
# encapsulation with getter and setter

# %%
class person:
    def __init__(self, name, age):
        self.__name = name      # Private attribute
        self.__age = age        # Private attribute

    # Getter methods
    def get_name(self):
        return self.__name

    def get_age(self):
        return self.__age


     # Setter methods
    def set_name(self, name):
        self.__name = name

    def set_age(self, age):
            self.__age = age

# %%
p = person('aditi',34)

# %%
p.get_name()
# Out:
# 'aditi'

# %%
p.get_age()
# Out:
# 34

# %%
# dunder method/magic method

# %%
dir(p)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_person__age',
#  '_person__name',
#  'get_age',
#  'get_name',
#  'set_age',
#  'set_name']

# %%
print(p)

# %%
 # __str__

# %%
class person:
    def __init__(self, name, age):
        self.__name = name      # Private attribute
        self.__age = age        # Private attribute

    # Getter methods
    def get_name(self):
        return self.__name

    def get_age(self):
        return self.__age


     # Setter methods
    def set_name(self, name):
        self.__name = name

    def set_age(self):
            return f"name ->{self.__name},age ->{self.__name}"

# %%
p = person('aditi',34)

# %%
print(p)

# %%
# create a menu driven app for banking simulation 
# check balance,deposite money,withdraw money ( u can add more things as u see fit to make the app better)

# %%
class BankAccount:

    def __init__(self, name, balance):
        self.name = name
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount
        print("Amount Deposited Successfully")

    def withdraw(self, amount):

        if amount <= self.balance:
            self.balance -= amount
            print("Amount Withdrawn Successfully")
        else:
            print("Insufficient Balance")

    def check_balance(self):
        print("Current Balance =", self.balance)


name = input("Enter Account Holder Name : ")
balance = float(input("Enter Initial Balance : "))

acc1 = BankAccount(name, balance)

while True:

    print("\n===== BANK MENU =====")
    print("1. Check Balance")
    print("2. Deposit Money")
    print("3. Withdraw Money")
    print("4. Exit")

    choice = int(input("Enter Choice : "))

    if choice == 1:
        acc1.check_balance()

    elif choice == 2:
        amount = float(input("Enter Deposit Amount : "))
        acc1.deposit(amount)

    elif choice == 3:
        amount = float(input("Enter Withdraw Amount : "))
        acc1.withdraw(amount)

    elif choice == 4:
        print("Thank You For Banking With Us")
        break

    else:
        print("Invalid Choice")
# Out:
# Enter Account Holder Name :  aaditi
# Enter Initial Balance :  70000
# ===== BANK MENU =====
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Enter Choice :  2
# Enter Deposit Amount :  500
# Amount Deposited Successfully
#
# ===== BANK MENU =====
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Enter Choice :  1
# Current Balance = 70500.0
#
# ===== BANK MENU =====
# 1. Check Balance
# 2. Deposit Money
# 3. Withdraw Money
# 4. Exit
# Enter Choice :  4
# Thank You For Banking With Us
