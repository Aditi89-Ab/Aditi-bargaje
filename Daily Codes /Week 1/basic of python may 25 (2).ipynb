# %%
print('hello')
# Out:
# hello

# %%
# add above -> A,below -> del -> x

# %% [markdown]
# IDENTIFIRES

# %%
NUM = 56

# %%
NUM1=8

# %%
name = "aditi"

# %%
print(name)
# Out:
# aditi

# %%
name
# Out:
# 'aditi'

# %%
rate of interest = 5
# Out:
#   Cell In[10], line 1
#     rate of interest = 5
#          ^
# SyntaxError: invalid syntax

# %%
rate_of_intersrest = 5

# %%
rate_of_intersrest
# Out:
# 5

# %%
Pass = 28

# %%
pass

# %%
num = 12

num2 = 78.44

name = "sia"

# %%
type(num)
# Out:
# int

# %%
type(num2)
# Out:
# float

# %%
type(name)
# Out:
# str

# %%
num= 21891286424 ** 234
num
# Out:
# ...

# %%
# float

# %%
num = 23e4

# %%
type(num)
# Out:
# float

# %%
num
# Out:
# 230000.0

# %%
# string

# %%
sent = "I like Python Programming"

# %%
print(sent)
# Out:
# I like Python Programming

# %%
# I like "Python" Programming
# I like 'Python' Programming

# %%
sent = 'I like "Python" Programming'
print(sent)
# Out:
# I like "Python" Programming

# %%
# simple addition program

# %%
a = 3
b = 5
z = a+b
print(z)
# Out:
# 8

# %%
a = 3; b = 5; z = a + b; print(z);
# Out:
# 8

# %%
a, b, c = 23, 56, "ok"

# %%
a
# Out:
# 23

# %%
b
# Out:
# 56

# %%
c
# Out:
# 'ok'
