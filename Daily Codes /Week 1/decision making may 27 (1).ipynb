# %%
num = int(input("enter the no"))
if num > 5:
     print ('yes')
# Out:
# enter the no 10
# yes

# %%
num = int(input("enter the no"))
if num > 5:
     print ('yes') 
else:
    print('no')
# Out:
# enter the no 5
# no

# %%
# write a program to check if the number is +ve or -ve

# %%
num=int(input("enter the number"))
if num > 0:
 print("positive number")
elif num == 0:
    print("zero")
else:
  print("negative")
# Out:
# enter the number 0
# zero

# %%
# check if the number is even or odd

# %%
num = int(input("enter the number"))
if num % 2 == 0:
    print("even number")
else:
          print("odd number")
# Out:
# enter the number 0
# even number

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
True + True +False
# Out:
# 2

# %%
a = 1
if a:
    print('exists')
# Out:
# exists

# %%
# check id the number is in between 50 and 100 or not (use nested if)

# %%
num = int(input("enter the number"))
if num > 50:
    if num <100:
        print("num is between 50 and 100:")
    else:
        print("num is not between 50 and 100:")
else:
    print("num is not between 50 and 100:")
# Out:
# enter the number 109
# num is not between 50 and 100:

# %%
# do the same with logical operator

# %%
num = int(input("enter the number"))
if num >= 50 and num <= 100:
    print ("satisfied")
else:
    print("not satisfied")
# Out:
# enter the number 200
# not satisfied

# %%
# reaad purchase cost and selling cast from the user
#state profit or loss and how much

# %%
selling_cost = int(input("enter the selling cost"))
purchase_cost = int(input("enter th purchase cost"))

if selling_cost > purchase_cost: 
   print (f"profit of => {selling_cost-purchase_cost}")
else:
   print(f"loss of => {purchase_cost - selling_cost} and ur time")
# Out:
# enter the selling cost 200
# enter th purchase cost 200
# loss of => 0 and ur time

# %%
# Out:
#   Cell In[32], line 1
#     """
#     ^
# _IncompleteInputError: incomplete input

# %%
""":
2020 ->leap
2017-> not leap
2000->leap
1800->not leap
""":
# Out:
#   Cell In[34], line 6
#     """:
#        ^
# SyntaxError: invalid syntax

# %%
# use nested if only ('and ' or 'or' not allowed

# %%
year = int(input("enter the year:"))
if year % 4 == 0: 
    if year % 100 == 0:
        if year % 400 == 0:
           print("century leap")
        else:
            print("century but not leap")
    else:
           print("leap")
else:
    print("not leap")
# Out:
# enter the year: 1800
# century but not leap

# %%
"""
take 3 numbers
find which is largest (use nested if only)
"""

# %%
num1 = int(input("enter num 1:"))
num2 = int(input("enter num2:"))
num3 = int(input("enter num3:"))

if num1 > num2 and num1 > num3:
    if num2 > num1 and num2 > num3:
        if num3 > num1 and num3 > num2:
            print("num1 is largest")
        else:
             print("num2 is largest")
    else: 
             print  ("num3 is largest") 
else:   
        print(" no one is largest")
# Out:
# enter num 1: 5
# enter num2: 10
# enter num3: 8
#  no one is largest

# %%
# menu driven

# %%
print("welcome to the dimple calculator")

num = int(input("enter the number"))
print("menu=>\n1. square\n2. cube\n3. check +ve or -ve")

ch = int(input("select ur choice"))

if ch == 11:
    print(num * num)
elif ch == 2:
    print(num ** 3)
elif ch == 3:
    if num > 0:
        print("positive")
    elif num == 0:
         print("zero")
    else:
         print("negative")
else:
    print("please visit nearest hospital to check ur eyes!!!! ")
# Out:
# welcome to the dimple calculator
# enter the number 45
# menu=>
# 1. square
# 2. cube
# 3. check +ve or -ve
# select ur choice 5
# please visit nearest hospital to check ur eyes!!!!

# %%
"""

# %%
print ("welcome")
text = input("enter the  string")  

print("menu =>\n1. upper \n2. lower\n3.replace")

ch = int(input("enter the choice"))

if ch == 1:
    print(f"(text.upper()")
elif ch == 2:
    print(f"(text.lower()")
elif ch == 3:
    r1 = input("which part u want to replace:")
    r2 = input("what u want to replace it with")
    new = text.replace(r1,r2)
    print(f"result ->(new)")
# Out:
# welcome
# enter the  string aditi
# menu =>
# 1. upper
# 2. lower
# 3.replace
# enter the choice 8
